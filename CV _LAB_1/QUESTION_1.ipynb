# %% [markdown]
# # QUESTION : 1

# %% [markdown]
# *  In following snippet of code we have import few important packages of python.
# *  We have also created object of all library so that we can acces and call them easily.
# *  Library we have used here is 'CV2','NUMPY','matplotlib'.

# %%
#...... KEYWORD: "import" used to import library which we are going to use it further

import cv2 as CV # CV is an object of cv2 library,cv2 is an COMPUTER VISION LIBRARY

import numpy as NP# NP is an object of numpy library,in numpy we can do all scietific calculator operation
import matplotlib.pyplot as PL# PL is an object of matplotlib.pyplot ,in matplotlib we all function which we can use for plottig stuff and morever all function named and syntax are very similar to what we have used in MATLAB

# %% [markdown]
#  * Here I have created a function for converting an RGB image into GRAYSCALE.
#  * First it will check that passed image is an grayscale or not.
#  * If it is grayscale then it will same image and it's dimension.
#  * If it is coloured image then it will convert it into grayscale and return it with it dimension.
#  * Approach we have used to conert it into grayscale is by performing average of all three channel.

# %%
# .........DEFINING A FUNCTION 'RGB2GRAY' for converting an RGB image to an GRAYSALE




def RGB2GRAY(y): 
    '''
   FIRST IT CHECK THAT PASSED IMAGE IS AN GRAYSCALE OR NOT .
   CONVERTIF IT IS GRAYSCLE IT WILL RETURNED THAT IMAGE AS IT IS.
   IF IT IS COLORED IMAGE THEN ONLY THIS FUNCTION WILL CONVERT IT IN TO 
   GRAYSCALE AND DISPLAY IT DIMENSION
'''
    if x.shape[2]!=3 : #  CHECKING WHETHER IMAGE IS REALLY GRAY SCALE OR NOT BY CHECKING IT DIMENSION
        I = y
        PL.figure(1)
        PL.imshow(I)
        PL.axis('off')
        PL.title('ORIGINAL GRAY IMAGE')
    if x.shape[2]==3:
        PL.figure(1)
        PL.imshow(y)
        PL.axis('off')   # FOR DISABLE THE AXIS FROM PLOT
        PL.title('ORIGINAL COLOR IMAGE')
        B = y[:,:,0]   # CHANNEL ONE OF RGB IMAGE WHICH CONTAIN ALL INTENSITY CORRESPOND TO BLUE COLOR
        G = y[:,:,1]   # CHANNEL TWO OF RGB IMAGE WHICH CONTAIN ALL INTENSITY CORRESPOND TO GREEN COLOR
        R = y[:,:,2]   # CHANNEL THREE OF RGB IMAGE WHICH CONTAIN ALL INTENSITY CORRESPOND TO RED COLOR
        A = (B/3+G/3+R/3)
        print('DIMENSION OF COLOR IMAGE\nROWS :{}\nCOLOMN : {}\nCHANNEL : {}'.format(y.shape[0],y.shape[1],y.shape[2]))
        PL.figure(2)
        PL.imshow(A,'gray')
        PL.axis('off')
        PL.title('GRAYSCALE IMAGE')
        print('DIMENSION OF GRAYSCALE IMAGE\nROWS :{}\nCOLOMN : {}'.format(A.shape[0],A.shape[1]))

# %% [markdown]
# * Now here we reading our image and calling user defined function RGB2GRAY

# %%
x = CV.imread('image1.jpg') #......READING AN IMAGE USING OBJECT CV(CV2 OBJECT)
RGB2GRAY(x)    # CALLING AN FUNCTION
# Out:
# DIMENSION OF COLOR IMAGE
# ROWS :225
# COLOMN : 300
# CHANNEL : 3
# DIMENSION OF GRAYSCALE IMAGE
# ROWS :225
# COLOMN : 300

# %%
import cv2 as CV

# %%
X = CV.imread('image1.jpg')

# %%
X.shape
# Out:
# (225, 300, 3)

# %%
X1 = CV.cvtColor(X,CV.COLOR_BGR2GRAY)

# %%
X1.shape
# Out:
# (225, 300)
